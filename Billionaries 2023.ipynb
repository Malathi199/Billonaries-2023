# %%
import pandas as pd
df = pd.read_csv('billionaires_2023.csv') 
print(df)
# Out:
#       year  month  rank net_worth  last_name first_name  \
# 0     2023      4     1   211.0 B    Arnault    Bernard
# 1     2023      4     2   180.0 B       Musk       Elon
# 2     2023      4     3   114.0 B      Bezos       Jeff
# 3     2023      4     4   107.0 B    Ellison      Larry
# 4     2023      4     5   106.0 B    Buffett     Warren
# ...    ...    ...   ...       ...        ...        ...
# 2635  2023      4  2540     1.0 B         Yu       Rong
# 2636  2023      4  2540     1.0 B  Yuengling    Richard
# 2637  2023      4  2540     1.0 B      Zhang    Gongyun
# 2638  2023      4  2540     1.0 B      Zhang    Guiping
# 2639  2023      4  2540     1.0 B      Zobel      Inigo
#
#                      full_name  birth_date   age gender  \
# 0     Bernard Arnault & family  1949-03-05  74.0   Male
# 1                    Elon Musk  1971-06-28  51.0   Male
# 2                   Jeff Bezos  1964-01-12  59.0   Male
# 3                Larry Ellison  1944-08-17  78.0   Male
# ...

# %%
df.head(10)
# Out:
#    year  month  rank net_worth  last_name first_name  \
# 0  2023      4     1   211.0 B    Arnault    Bernard
# 1  2023      4     2   180.0 B       Musk       Elon
# 2  2023      4     3   114.0 B      Bezos       Jeff
# 3  2023      4     4   107.0 B    Ellison      Larry
# 4  2023      4     5   106.0 B    Buffett     Warren
# 5  2023      4     6   104.0 B      Gates       Bill
# 6  2023      4     7    94.5 B  Bloomberg    Michael
# 7  2023      4     8    93.0 B  Slim Helu     Carlos
# 8  2023      4     9    83.4 B     Ambani     Mukesh
# 9  2023      4    10    80.7 B    Ballmer      Steve
#
#                    full_name  birth_date   age gender country_of_citizenship  \
# 0   Bernard Arnault & family  1949-03-05  74.0   Male                 France
# 1                  Elon Musk  1971-06-28  51.0   Male          United States
# 2                 Jeff Bezos  1964-01-12  59.0   Male          United States
# ...

# %%
import pandas as pd
# Read data into a DataFrame
df= pd.read_csv('billionaires_2023.csv')
# Convert the 'net_worth' column to numeric (removing the 'B' suffix)
df['net_worth'] = df['net_worth'].replace({'B': ''}, regex=True).astype(float)
# Calculate the mean of 'net_worth' column
mean_net_worth = df['net_worth'].mean()
print("Mean net worth:")
print(mean_net_worth)
# Out:
# Mean net worth:
# 4.623787878787878

# %%
import numpy as np
import pandas as pd
# Read data into a DataFrame
df= pd.read_csv('billionaires_2023.csv')
mean_of_age=df['age']
# Mean
mean = np.mean(mean_of_age)
print("Mean of age:", mean)
# Out:
# Mean of age: 65.13902912621359

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Read data into a DataFrame
df = pd.read_csv('billionaires_2023.csv')
# Clean data: remove any rows with missing values in 'business_category' column
df = df.dropna(subset=['business_category'])
# Extracting business category counts 
business = df['business_category'].value_counts()
# Labels for the pie chart
labels = business.index
# Data for the pie chart
sizes = business.values
# Explode parameter
explode = tuple([0.1] * len(labels)) 
 # Explode all slices slightly for emphasis
# Plotting the pie chart
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=45, pctdistance=0.75)
plt.title("Business Categories of Billionaires")
# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')
# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Read data into a DataFrame
df = pd.read_csv('billionaires_2023.csv')
# Extracting business category counts
business = df['business_category'].value_counts()
# Plotting a bar chart
# Plotting
plt.figure(figsize=(15, 8))
plt.bar(business.index, business.values)
# Rotation of the bars names
plt.xticks(rotation=90)
# Title and labels
plt.title("Business category of Billionaires")
plt.xlabel("business_category")
plt.ylabel("Count")
# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Read data into a DataFrame
df = pd.read_csv('billionaires_2023.csv')
# Assuming the DataFrame contains a 'gender' column
# Extracting gender counts
gender_counts = df['gender'].value_counts()
# Labels for the pie chart
labels = gender_counts.index
# Data for the pie chart
sizes = gender_counts.values
# Explode parameter
explode = (0, 0)  
# Plotting the pie chart
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=140)
# Title for the plot
plt.title("Gender percentage of Billionaires")
# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')
# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Read data into a DataFrame
df = pd.read_csv('billionaires_2023.csv')
# Assuming the DataFrame contains a 'age' column
# Extracting gender counts
age_counts = df['age'].value_counts()
# Plotting a bar chart
# Plotting
plt.figure(figsize=(15, 8))
plt.bar(age_counts.index, age_counts.values)
# Title and labels
plt.title("Age of Billionaires")
plt.xlabel("Ages")
plt.ylabel("Count")
# Show plot
plt.show()
